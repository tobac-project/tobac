# %% [markdown]
# tobac example: Compute bulk statistics as a postprocessing step
# ===
#
# Instead of during the feature detection or segmentation process, you can also calculate bulk statistics of your detected/tracked objects as a postprocessing step, i.e. based on a segmentation mask. This makes it possible to combine different datasets and derive statistics for your detected features based on other input fields (e.g., get precipitation statistics under cloud features that were segmented based on brightness temperatures or outgoing longwave radiation).
#
# This notebook shows an example for how to read in a segmentation mask and input data with the same grid spacing and dimensions to compute statistics for the detected features. We use here the segmentation mask and data from [our example for precipitation tracking](https://github.com/tobac-project/tobac/blob/main/examples/Example_Precip_Tracking/Example_Precip_Tracking.ipyn) (see also ...).

# %%
# Import libraries
import iris
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import iris.plot as iplt
import iris.quickplot as qplt
import datetime
import shutil
from six.moves import urllib
from pathlib import Path
# %matplotlib inline

# %%
# Import tobac itself
import tobac
print('using tobac version', str(tobac.__version__))
# Out:
# using tobac version 1.5.0

# %%
# Disable a few warnings:
import warnings
warnings.filterwarnings('ignore', category=UserWarning, append=True)
warnings.filterwarnings('ignore', category=RuntimeWarning, append=True)
warnings.filterwarnings('ignore', category=FutureWarning, append=True)
warnings.filterwarnings('ignore',category=pd.io.pytables.PerformanceWarning)

# %%
# read in mask file from segmentation process 
savedir=Path("Save")
Features_Precip = iris.load_cube(savedir / 'Mask_Segmentation_precip.nc')
Precip = iris.load_cube('../climate-processes-tobac_example_data-b3e69ee/data/Example_input_Precip.nc')

# %%
import xarray as xr 
Mask_Precip = xr.open_dataset(savedir / 'Mask_Segmentation_precip.nc').segmentation_mask
Features_Precip = pd.read_hdf(savedir / 'Features_Precip.h5', 'table')
Precip = xr.open_dataset('../climate-processes-tobac_example_data-b3e69ee/data/Example_input_Precip.nc').surface_precipitation_average

# %% [markdown]
# **Get bulk statistics from mask file**
#
# You can decide which statistics to calculate by providing a dictionary with the name of the metric as keys (this will be the name of the column added to the dataframe) and functions as values. Note that it is also possible to provide input parameter to these functions.

# %%
from tobac.utils.general import get_statistics_from_mask

# %% [markdown]
# #### Defining the dictionary for the statistics to be calculated

# %%
statistics = {}
statistics['mean_precip'] = np.mean
statistics['total_precip'] = np.sum
statistics['max_precip'] = np.max

# %% [markdown]
# For some functions, we need to provide additional input parameters, e.g. [np.percentile()](https://numpy.org/doc/stable/reference/generated/numpy.percentile.html). These can be provided as key word arguments in form of a dictionary. So instead of the function, you can provide a tuple with both the function and its respective input parameters:

# %%
statistics['percentiles'] = (np.percentile, {'q': [95,99]})

# %%
Mask_Precip = iris.load_cube(savedir / 'Mask_Segmentation_precip.nc', 'segmentation_mask')
Precip = iris.load_cube('../climate-processes-tobac_example_data-b3e69ee/data/Example_input_Precip.nc', 'surface_precipitation_average')

# %%
Precip
# Out:
# <iris 'Cube' of surface_precipitation_average / (mm h-1) (time: 47; south_north: 198; west_east: 198)>

# %%
features_with_stats = get_statistics_from_mask(Mask_Precip, Precip, features = Features_Precip, func_dict = statistics)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 features_with_stats = get_statistics_from_mask(Mask_Precip, Precip, features = Features_Precip, func_dict = statistics)
#
# File ~/Desktop/projects/tobac/tobac/tobac/utils/internal.py:143, in iris_to_xarray.<locals>.wrapper(*args, **kwargs)
#     130 kwargs_new = dict(
#     131     zip(
#     132         kwargs.keys(),
#    (...)
#     139     )
#     140 )
#     141 # print(args)
#     142 # print(kwargs)
# --> 143 output = func(*args, **kwargs_new)
#     144 if type(output) == tuple:
#     145     output = tuple(
#     146         [
#     147             xarray.DataArray.to_iris(output_item)
#    (...)
#     151         ]
#     152     )
#
# File ~/Desktop/projects/tobac/tobac/tobac/utils/general.py:832, in get_statistics_from_mask(segmentation_mask, features, func_dict, index, default, id_column, *fields)
#     827         raise ValueError(
#     828             "The labels of the segmentation mask and the feature dataframe do not seem to match. Please make sure you provide the correct input feature dataframe to calculate the bulk statistics. "
#     829         )
#     830     else:
#     831         # make sure that features are not double-defined
# --> 832         features = get_statistics(
#     833             segmentation_mask_t,
#     834             field_t,
#     835             features=features,
#     836             func_dict=func_dict,
#     837             default=default,
#     838             index=index,
#     839             id_column=id_column,
#     840         )
#     842 return features
#
# File ~/Desktop/projects/tobac/tobac/tobac/utils/general.py:681, in get_statistics(labels, features, func_dict, index, default, id_column, *fields)
#     678         raise ValueError("Input labels and field do not have the same shape")
#     680 if index is None:
# --> 681     index = range(int(np.nanmin(labels[labels > 0])), int(np.nanmax(labels) + 1))
#     682 else:
#     683     # get the statistics only for specified feature objects
#     684     if np.max(index) > np.max(labels):
#
# File ~/anaconda3/envs/fresh-python/lib/python3.11/site-packages/dask/array/core.py:1759, in Array.__array_function__(self, func, types, args, kwargs)
#    1756 if has_keyword(da_func, "like"):
#    1757     kwargs["like"] = self
# -> 1759 return da_func(*args, **kwargs)
#
# File ~/anaconda3/envs/fresh-python/lib/python3.11/site-packages/dask/array/reductions.py:595, in nanmin(a, axis, keepdims, split_every, out)
#     592 @derived_from(np)
#     593 def nanmin(a, axis=None, keepdims=False, split_every=None, out=None):
#     594     if np.isnan(a.size):
# --> 595         raise ValueError(f"Arrays chunk sizes are unknown. {unknown_chunk_message}")
#     596     if a.size == 0:
#     597         raise ValueError(
#     598             "zero-size array to reduction operation fmin which has no identity"
#     599         )
#
# ValueError: Arrays chunk sizes are unknown.
#
# A possible solution: https://docs.dask.org/en/latest/array-chunks.html#unknown-chunks
# Summary: to compute chunks sizes, use
#
#    x.compute_chunk_sizes()  # for Dask Array `x`
#    ddf.to_dask_array(lengths=True)  # for Dask DataFrame `ddf`

# %% [markdown]
# ### Look at the output:

# %%
features_with_stats.head()
# Out:
#    frame  idx      hdim_1      hdim_2  num  threshold_value mean_precip  \
# 0      0    1   50.065727  139.857477    9                1    1.629695
# 1      0   15  120.527119  172.500325    4                1    1.409547
# 2      0   18  126.779273  145.368401   15                1    2.441526
# 3      0   34  111.611369  155.452030    4                2    1.938501
# 4      0   35  111.765231  164.938866    8                2    2.486886
#
#   total_precip max_precip                                  percentiles  ...  \
# 0    16.296951   2.289786    ([2.221776068210602, 2.276183712482452],)  ...
# 1    14.095468   1.819811  ([1.8030404090881347, 1.8164567756652832],)  ...
# 2    26.856783   3.771701    ([3.710712432861328, 3.759503173828125],)  ...
# 3    36.831512   4.067666    ([3.940941762924194, 4.042321195602417],)  ...
# 4    49.737709   4.380943   ([4.087516045570374, 4.3222578477859495],)  ...
#
#                timestr south_north   west_east  projection_y_coordinate  \
# 0  2013-06-19 20:05:00  331.065727  420.857477            165782.863285
# 1  2013-06-19 20:05:00  401.527119  453.500325            201013.559414
# 2  2013-06-19 20:05:00  407.779273  426.368401            204139.636582
# 3  2013-06-19 20:05:00  392.611369  436.452030            196555.684682
# 4  2013-06-19 20:05:00  392.765231  445.938866            196632.615461
#
#             y   latitude  longitude  projection_x_coordinate           x  \
# 0  331.065727  29.846362 -94.172015            210678.738492  420.857477
# 1  401.527119  30.166929 -93.996892            227000.162468  453.500325
# 2  407.779273  30.196499 -94.139960            213434.200454  426.368401
# 3  392.611369  30.126871 -94.087317            218476.015240  436.452030
# 4  392.765231  30.127221 -94.037226            223219.433218  445.938866
#
#    ncells
# 0      10
# 1      10
# 2      11
# 3      19
# 4      20
#
# [5 rows x 22 columns]
